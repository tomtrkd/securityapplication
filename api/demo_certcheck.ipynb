# %%
# !pip install pyopenssl
# !pip install cryptography
# !pip install idna
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyopenssl in c:\users\damien\appdata\roaming\python\python39\site-packages (20.0.1)
# Requirement already satisfied: cryptography>=3.2 in c:\users\damien\appdata\roaming\python\python39\site-packages (from pyopenssl) (3.4.7)
# Requirement already satisfied: six>=1.5.2 in c:\users\damien\appdata\roaming\python\python39\site-packages (from pyopenssl) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\damien\appdata\roaming\python\python39\site-packages (from cryptography>=3.2->pyopenssl) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\damien\appdata\roaming\python\python39\site-packages (from cffi>=1.12->cryptography>=3.2->pyopenssl) (2.20)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cryptography in c:\users\damien\appdata\roaming\python\python39\site-packages (3.4.7)
# Requirement already satisfied: cffi>=1.12 in c:\users\damien\appdata\roaming\python\python39\site-packages (from cryptography) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\damien\appdata\roaming\python\python39\site-packages (from cffi>=1.12->cryptography) (2.20)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: idna in c:\users\damien\appdata\roaming\python\python39\site-packages (3.2)

# %%
import pickle

from OpenSSL import SSL
from cryptography import x509
from cryptography.x509.oid import NameOID
import idna

from socket import socket
from collections import namedtuple

# %%
file_in = open("top1m.pickle","rb")
top1m = pickle.load(file_in)

# %%
HostInfo = namedtuple(field_names='cert hostname peername', typename='HostInfo')

def get_certificate(hostname, port):
    hostname_idna = idna.encode(hostname)
    sock = socket()

    sock.connect((hostname, port))
    peername = sock.getpeername()
    ctx = SSL.Context(SSL.SSLv23_METHOD) # most compatible
    ctx.check_hostname = False
    ctx.verify_mode = SSL.VERIFY_NONE

    sock_ssl = SSL.Connection(ctx, sock)
    sock_ssl.set_connect_state()
    sock_ssl.set_tlsext_host_name(hostname_idna)
    sock_ssl.do_handshake()
    cert = sock_ssl.get_peer_certificate()
    crypto_cert = cert.to_cryptography()
    sock_ssl.close()
    sock.close()

    return HostInfo(cert=crypto_cert, peername=peername, hostname=hostname)

# %%
checked = 0
notfound = 0
DV_Count = 0
EV_Count = 0
OV_Count = 0
no_connection = 0
count = 1
DV = "2.23.140.1.2.1"
OV = "2.23.140.1.2.2"
EV = "2.23.140.1.1"


for domain in top1m:
    print(domain)
    try:
        test_data = get_certificate(domain, 443)

        try:
            cert_pol = test_data.cert.extensions.get_extension_for_class(x509.CertificatePolicies)
            cert_pol = str(cert_pol)

            if DV in cert_pol:
                print("DV Cert")
                DV_Count = DVOV_Count + 1

            elif EV in cert_pol:
                print("EV Cert")
                EV_Count = EV_Count + 1

            elif OV in cert_pol:
                print("OV Cert")
                OV_Count = OV_Count + 1

            else:
                print("No CertificatePolicies Found")
                notfound = notfound + 1
        except:
            print("No CertificatePolicies Found")
            notfound = notfound + 1
    except:
        print("can not connect")
        no_connection = no_connection + 1
    
    print("Number not found: " + str(notfound) + " of check : " + str(count))
    print("Number Rufused Connection: " + str(no_connection))
    print("DV: " + str(DV_Count) + " EV: " + str(EV_Count) + " OV: " + str(OV_Count))
    count = count +1
    print("\n")
# Out:
# e11990.a.akamaiedge.net
# OV Cert
# Number not found: 0 of check : 1
# Number Rufused Connection: 0
# DV: 0 EV: 0 OV: 1
#
#
# mobile-contacts.zoominfo.com
# OV Cert
# Number not found: 0 of check : 2
# Number Rufused Connection: 0
# DV: 0 EV: 0 OV: 2
#
#
# momsandmunchkins.ca
# OV Cert
# Number not found: 0 of check : 3
# Number Rufused Connection: 0
# DV: 0 EV: 0 OV: 3
#
#
# intel.com
# OV Cert
# Number not found: 0 of check : 4
# Number Rufused Connection: 0
# DV: 0 EV: 0 OV: 4
#
#
# viewpointeservices.com
# can not connect
# Number not found: 0 of check : 5
# Number Rufused Connection: 1
# DV: 0 EV: 0 OV: 4
#
#
# pornogratisdiario.com
# DV Cert
# No CertificatePolicies Found
# Number not found: 1 of check : 6
# Number Rufused Connection: 1
# DV: 0 EV: 0 OV: 4
#
#
# entrance.mystripclub.com
# DV Cert
# No CertificatePolicies Found
# Number not found: 2 of check : 7
# Number Rufused Connection: 1
# DV: 0 EV: 0 OV: 4
#
#
# cps-mp.heartlandmosaic.com
# OV Cert
# Number not found: 2 of check : 8
# Number Rufused Connection: 1
# DV: 0 EV: 0 OV: 5
#
#
# relay-6dfe183e.net.anydesk.com
# No CertificatePolicies Found
# Number not found: 3 of check : 9
# Number Rufused Connection: 1
# DV: 0 EV: 0 OV: 5
#
#
# ssl-metrics.tim.it
# OV Cert
# Number not found: 3 of check : 10
# Number Rufused Connection: 1
# DV: 0 EV: 0 OV: 6
#
#
# ns-1932.awsdns-49.co.uk
# can not connect
# Number not found: 3 of check : 11
# Number Rufused Connection: 2
# DV: 0 EV: 0 OV: 6
#
#
# r4---sn-a5mlrn7r.c.2mdn.net
# can not connect
# Number not found: 3 of check : 12
# Number Rufused Connection: 3
# DV: 0 EV: 0 OV: 6
#
#
# edge-001.usdal2.icloud-content.com
# OV Cert
# Number not found: 3 of check : 13
# Number Rufused Connection: 3
# DV: 0 EV: 0 OV: 7
#
#
# cdn3.shoptagr.com
# DV Cert
# No CertificatePolicies Found
# Number not found: 4 of check : 14
# Number Rufused Connection: 3
# DV: 0 EV: 0 OV: 7
#
#
# api.ejoy.io
# DV Cert
# No CertificatePolicies Found
# Number not found: 5 of check : 15
# Number Rufused Connection: 3
# DV: 0 EV: 0 OV: 7
#
#
# e14375.b.akamaiedge.net
# OV Cert
# Number not found: 5 of check : 16
# Number Rufused Connection: 3
# DV: 0 EV: 0 OV: 8
#
#
# m27.qejegnn.com
# No CertificatePolicies Found
# Number not found: 6 of check : 17
# Number Rufused Connection: 3
# DV: 0 EV: 0 OV: 8
#
#
# 21.push2his.eastmoney.com
# OV Cert
# Number not found: 6 of check : 18
# Number Rufused Connection: 3
# DV: 0 EV: 0 OV: 9
#
#
# lindenlab.com
# DV Cert
# No CertificatePolicies Found
# Number not found: 7 of check : 19
# Number Rufused Connection: 3
# DV: 0 EV: 0 OV: 9
#
#
# remote-service.rnd.huawei.com
# can not connect
# Number not found: 7 of check : 20
# Number Rufused Connection: 4
# DV: 0 EV: 0 OV: 9
#
#
# newcap.leanstream.co
# DV Cert
# No CertificatePolicies Found
# Number not found: 8 of check : 21
# Number Rufused Connection: 4
# DV: 0 EV: 0 OV: 9
#
#
# ferrellgaspartnerslp-my.sharepoint.com
# OV Cert
# Number not found: 8 of check : 22
# Number Rufused Connection: 4
# DV: 0 EV: 0 OV: 10
#
#
# img.guess.com
# DV Cert
# No CertificatePolicies Found
# Number not found: 9 of check : 23
# Number Rufused Connection: 4
# DV: 0 EV: 0 OV: 10
#
#
# embed-cors-proxy.supersonic.acast.com
# DV Cert
# No CertificatePolicies Found
# Number not found: 10 of check : 24
# Number Rufused Connection: 4
# DV: 0 EV: 0 OV: 10
#
#
# www.unicode.org
# DV Cert
# No CertificatePolicies Found
# Number not found: 11 of check : 25
# Number Rufused Connection: 4
# DV: 0 EV: 0 OV: 10
#
#
# openai.jamfcloud.com
# DV Cert
# No CertificatePolicies Found
# Number not found: 12 of check : 26
# Number Rufused Connection: 4
# DV: 0 EV: 0 OV: 10
#
#
# clinical.changehealthcare.com
# can not connect
# Number not found: 12 of check : 27
# Number Rufused Connection: 5
# DV: 0 EV: 0 OV: 10
#
#
# doc-0g-98-apps-viewer.googleusercontent.com
# OV Cert
# Number not found: 12 of check : 28
# Number Rufused Connection: 5
# DV: 0 EV: 0 OV: 11
#
#
# content.resale.ticketmaster.com
# DV Cert
# No CertificatePolicies Found
# Number not found: 13 of check : 29
# Number Rufused Connection: 5
# DV: 0 EV: 0 OV: 11
#
#
# r1---sn-8vq54vox03-xqpe.googlevideo.com
# can not connect
# Number not found: 13 of check : 30
# Number Rufused Connection: 6
# DV: 0 EV: 0 OV: 11
#
#
# jackrabbitsystems.com
# DV Cert
# No CertificatePolicies Found
# Number not found: 14 of check : 31
# Number Rufused Connection: 6
# DV: 0 EV: 0 OV: 11
#
#
# nextmd.com
# DV Cert
# No CertificatePolicies Found
# Number not found: 15 of check : 32
# Number Rufused Connection: 6
# DV: 0 EV: 0 OV: 11
#
#
# www.contextotucuman.com
# DV Cert
# No CertificatePolicies Found
# Number not found: 16 of check : 33
# Number Rufused Connection: 6
# DV: 0 EV: 0 OV: 11
#
#
# i5-img.7tv.de
# OV Cert
# Number not found: 16 of check : 34
# Number Rufused Connection: 6
# DV: 0 EV: 0 OV: 12
#
#
# scontent.fteq1-1.fna.fbcdn.net
# OV Cert
# Number not found: 16 of check : 35
# Number Rufused Connection: 6
# DV: 0 EV: 0 OV: 13
#
#
# ateb.com
# OV Cert
# Number not found: 16 of check : 36
# Number Rufused Connection: 6
# DV: 0 EV: 0 OV: 14
#
#
# evony.com
# OV Cert
# Number not found: 16 of check : 37
# Number Rufused Connection: 6
# DV: 0 EV: 0 OV: 15
#
#
# n01b-e2.revma.ihrhls.com
# can not connect
# Number not found: 16 of check : 38
# Number Rufused Connection: 7
# DV: 0 EV: 0 OV: 15
#
#
# cdn.theyarehuge.com
# DV Cert
# No CertificatePolicies Found
# Number not found: 17 of check : 39
# Number Rufused Connection: 7
# DV: 0 EV: 0 OV: 15
#
#
# scmpmagazines.com
# OV Cert
# Number not found: 17 of check : 40
# Number Rufused Connection: 7
# DV: 0 EV: 0 OV: 16
#
#
# yellowstonenationalparklodges.com
# DV Cert
# No CertificatePolicies Found
# Number not found: 18 of check : 41
# Number Rufused Connection: 7
# DV: 0 EV: 0 OV: 16
#
#
# rpp-noticias.io
# can not connect
# Number not found: 18 of check : 42
# Number Rufused Connection: 8
# DV: 0 EV: 0 OV: 16
#
#
# m9.giktmlk.com
# can not connect
# Number not found: 18 of check : 43
# Number Rufused Connection: 9
# DV: 0 EV: 0 OV: 16
#
#
# shop.axs.com
# DV Cert
# No CertificatePolicies Found
# Number not found: 19 of check : 44
# Number Rufused Connection: 9
# DV: 0 EV: 0 OV: 16
#
#
# callblock.ksmobile.net
# can not connect
# Number not found: 19 of check : 45
# Number Rufused Connection: 10
# DV: 0 EV: 0 OV: 16
#
#
# r6---sn-hp57kn67.gvt1.com
# can not connect
# Number not found: 19 of check : 46
# Number Rufused Connection: 11
# DV: 0 EV: 0 OV: 16
#
#
# w86-233.abo.wanadoo.fr
# can not connect
# Number not found: 19 of check : 47
# Number Rufused Connection: 12
# DV: 0 EV: 0 OV: 16
#
#
# freeviewplay.net
# can not connect
# Number not found: 19 of check : 48
# Number Rufused Connection: 13
# DV: 0 EV: 0 OV: 16
#
#
# route.onelink.me
# DV Cert
# No CertificatePolicies Found
# Number not found: 20 of check : 49
# Number Rufused Connection: 13
# DV: 0 EV: 0 OV: 16
#
#
# images.magnetmail.net
# DV Cert
# No CertificatePolicies Found
# Number not found: 21 of check : 50
# Number Rufused Connection: 13
# DV: 0 EV: 0 OV: 16
#
#
# doc-00-5s-apps-viewer.googleusercontent.com
# can not connect
# Number not found: 21 of check : 51
# Number Rufused Connection: 14
# DV: 0 EV: 0 OV: 16
#
#
# z-m-scontent.fsub6-1.fna.fbcdn.net
# OV Cert
# Number not found: 21 of check : 52
# Number Rufused Connection: 14
# DV: 0 EV: 0 OV: 17
#
#
# www.nsf.gov
# EV Cert
# Number not found: 21 of check : 53
# Number Rufused Connection: 14
# DV: 0 EV: 1 OV: 17
#
#
# www.taccontest.com

# %%
print("Number could not connnect to: " + str(no_connection))
print("Number not found: " + str(notfound))
print("Number of DV: " + str(DV_Count))
print("Number of EV: " + str(EV_Count))
print("Number of OV: " + str(OV_Count))
